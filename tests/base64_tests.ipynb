# %% [markdown]
# # Base64 encoding and decoding using Python

# %% [markdown]
# Resource: [Envato Tuts+ - Base64 Encoding and Decoding Using Python](https://code.tutsplus.com/tutorials/base64-encoding-and-decoding-using-python--cms-25588).

# %% [markdown]
# ## Required librairies

# %%
import base64
from IPython.display import Image, display

# %% [markdown]
# ## Encoding text

# %%
text_binary = b'Hey'
print(f'text_binary: {text_binary}')  # b'Hey'

text_b64encode = base64.b64encode(text_binary)
print(f'text_b64encode: {text_b64encode}')  # b'SGV5'
# Out:
# text_binary: b'Hey'
# text_b64encode: b'SGV5'

# %% [markdown]
# ## Encoding image

# %%
image = open('deer.png', 'rb')
# Open binary file in read mode
image_read = image.read()
image_b64encode = base64.b64encode(image_read)
print(f'image_b64encode: {image_b64encode}')
# Out:
# image_b64encode: b'...'

# %% [markdown]
# ## Decoding image

# %%
image_b64decode = base64.b64decode(image_b64encode)
# Create a writable image and write image
image_result = open('deer_decode.png', 'wb') 
# Note that following command returns the size of the image in Bytes
image_result.write(image_b64decode)
# Out:
# 19046

# %% [markdown]
# ## Decoding image from BusyContacts app

# %%
string_kristof_pic_raw = """
PHOTO:data:image/jpeg;base64\,/9j/4AAQSkZJRgABAQAAAQABAAD/4QBsRXhpZgAASUkqA
 
 LehHywAAAAP/Z
"""

# %%
kristof_pic_b64encode = string_kristof_pic_raw.split(',')[-1].replace('\n ','')
print(f'kristof_pic_b64encode:\n{kristof_pic_b64encode}')
# Out:
# kristof_pic_b64encode:
# ...

# %%
# ✅ Working!
kristof_pic_b64decode = base64.b64decode(kristof_pic_b64encode)
# Create a writable image and write image
image_result = open('kristof_decode.png', 'wb') 
image_result.write(kristof_pic_b64decode)
# Out:
# 13752

# %%
display(Image(filename='kristof_decode.png'))

# %% [markdown]
# Testing problematic Jaiyam Sharma's picture:

# %%
string_jaiyam_pic_raw = """
PHOTO:data:image/jpeg;base64\,/9j/4AAQSkZJRgABAQAASABIAAD/4QBARXhpZgAATU0AK
 
"""

# %%
jayiam_pic_b64encode = string_jaiyam_pic_raw.split(',')[-1].replace('\n ','')
print(f'jayiam_pic_b64encode:\n{jayiam_pic_b64encode}')
# Out:
# jayiam_pic_b64encode:
# ...

# %%
jayiam_pic_b64encode = '...'

# %%
# ✅ Working!
jayiam_pic_b64decode = base64.b64decode(jayiam_pic_b64encode)
# Create a writable image and write image
image_result = open('jayiam_decode.png', 'wb')
image_result.write(jayiam_pic_b64decode)
# Out:
# 25170

# %%
display(Image(filename='jayiam_decode.png'))
